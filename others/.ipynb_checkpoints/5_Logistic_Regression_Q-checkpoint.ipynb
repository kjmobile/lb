# %% [markdown]
# <a href="https://colab.research.google.com/github/kjmobile/lb/blob/main/5_Logistic_Regression_Q.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 1 Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['figure.figsize']=(3,3)

# %% [markdown]
# -  1.1. Logistic Function (aka, Sigmoid Function) :
# $$P(y=1|X) = \frac{1}{1+e^{-z}}$$
#
#
# $$\text where $$
#
# $$ z = \beta_0 + \beta_1X$$

# %%
plt.scatter(x=range(10), y=np.array([0]*4+[1]*6))

# %%
import scipy.stats as stats

# %%
stats.pearsonr(x=range(1,11), y=np.array([0]*4+[1]*6))
# Out:
# PearsonRResult(statistic=0.8528028654224417, pvalue=0.001712874149321464)

# %%
x=np.linspace(-5,5,100)

# %% [markdown]
# $z=\beta_1*x+\beta_0$

# %%
z=2*x + 1

# %%
plt.plot(1/(1+np.exp(-z)))
plt.hlines(y=.5, xmin=0, xmax=100, ls='--', color=[.8,.8,.8])

# %%
p=1/(1+np.exp(-z))

# %% [raw]
# 1/p=1+np.exp(-z)
# (1/p)-1=np.exp(-z)
# (1-p)/p =np.exp(-z)
# p/(1-p)=np.exp(z)
# ln(p/(1-p))=beta_1*x+beta_0

# %% [markdown]
# $\ln\left({\frac{p}{1-p}}\right) = \beta_1 x + \beta_0 $

# %% [markdown]
# ## 2 Import Dataset, titanic

# %%
# prompt: get titanic dataset from sns
data=pd.read_csv("https://raw.githubusercontent.com/kjmobile/data/main/ml/titanic.csv")

# %%
data.head(2)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#    SibSp  Parch     Ticket Embarked  Survived
# 0      1      0  A/5 21171        S         0
# 1      1      0   PC 17599        C         1

# %% [markdown]
# ## 3 Checking titanic

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 889 entries, 0 to 888
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Pclass    889 non-null    int64
#  1   Name      889 non-null    object
#  2   Sex       889 non-null    object
#  3   Age       889 non-null    float64
#  4   SibSp     889 non-null    int64
#  5   Parch     889 non-null    int64
#  6   Ticket    889 non-null    object
#  7   Embarked  889 non-null    object
#  8   Survived  889 non-null    int64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 62.6+ KB

# %%
data.corr(numeric_only=True)
# Out:
#             Pclass       Age     SibSp     Parch  Survived
# Pclass    1.000000 -0.336512  0.081656  0.016824 -0.335549
# Age      -0.336512  1.000000 -0.232543 -0.171485 -0.069822
# SibSp     0.081656 -0.232543  1.000000  0.414542 -0.034040
# Parch     0.016824 -0.171485  0.414542  1.000000  0.083151
# Survived -0.335549 -0.069822 -0.034040  0.083151  1.000000

# %%
sns.heatmap(data.corr(numeric_only=True), cmap='coolwarm', annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ## 4 Preprocessing: Converting Categorical Variables (Dummy Variables and One-Hot Encoding)

# %%
data.head(2)
# Out:
#    Pclass                                               Name     Sex   Age  \
# 0       3                            Braund, Mr. Owen Harris    male  22.0
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#    SibSp  Parch     Ticket Embarked  Survived
# 0      1      0  A/5 21171        S         0
# 1      1      0   PC 17599        C         1

# %%
titanic = data.drop(['Name','Ticket'], axis=1)
titanic.head()
# Out:
#    Pclass     Sex   Age  SibSp  Parch Embarked  Survived
# 0       3    male  22.0      1      0        S         0
# 1       1  female  38.0      1      0        C         1
# 2       3  female  26.0      0      0        S         1
# 3       1  female  35.0      1      0        S         1
# 4       3    male  35.0      0      0        S         0

# %%
# We use dummy coding (instead of one hot encoding this time by setting drop_first=True)
titanic_dum=pd.get_dummies(titanic, columns = ['Sex','Embarked'], drop_first=True)

# %%
titanic_dum
# Out:
#      Pclass   Age  SibSp  Parch  Survived  Sex_male  Embarked_Q  Embarked_S
# 0         3  22.0      1      0         0      True       False        True
# 1         1  38.0      1      0         1     False       False       False
# 2         3  26.0      0      0         1     False       False        True
# 3         1  35.0      1      0         1     False       False        True
# 4         3  35.0      0      0         0      True       False        True
# ..      ...   ...    ...    ...       ...       ...         ...         ...
# 884       2  27.0      0      0         0      True       False        True
# 885       1  19.0      0      0         1     False       False        True
# 886       3  28.0      1      2         0     False       False        True
# 887       1  26.0      0      0         1      True       False       False
# 888       3  32.0      0      0         0      True        True       False
#
# [889 rows x 8 columns]

# %% [markdown]
# ## 5 Modeling and Predicting

# %%
from sklearn.model_selection import train_test_split

X = titanic_dum.drop('Survived', axis = 1)
y = titanic_dum['Survived']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)

# %%
from sklearn.linear_model import LogisticRegression

# %%
X_train.head(2)
# Out:
#      Pclass   Age  SibSp  Parch  Sex_male  Embarked_Q  Embarked_S
# 776       3   5.0      0      0     False       False        True
# 781       1  29.0      0      0      True       False        True

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
# Predict category
pred = lr.predict(X_test)

# %%
# to obtain actual probablities
lr.predict_proba(X_test)
# Out:
# array([[0.92552334, 0.07447666],
#        [0.37707074, 0.62292926],
#        [0.92227876, 0.07772124],
#        [0.44994828, 0.55005172],
#        [0.88488134, 0.11511866],
#        [0.18729717, 0.81270283],
#        [0.9071155 , 0.0928845 ],
#        [0.79491173, 0.20508827],
#        [0.89851031, 0.10148969],
#        [0.34917409, 0.65082591],
#        [0.37012255, 0.62987745],
#        [0.44692941, 0.55307059],
#        [0.64980908, 0.35019092],
#        [0.26687483, 0.73312517],
#        [0.08277617, 0.91722383],
#        [0.88459445, 0.11540555],
#        [0.83809281, 0.16190719],
#        [0.6059575 , 0.3940425 ],
#        [0.67890858, 0.32109142],
#        [0.88488134, 0.11511866],
#        [0.25098584, 0.74901416],
#        [0.25402495, 0.74597505],
#        [0.92541727, 0.07458273],
#        [0.95904087, 0.04095913],
#        [0.05462083, 0.94537917],
#        [0.18674171, 0.81325829],
#        [0.29092997, 0.70907003],
#        [0.90016914, 0.09983086],
#        [0.93769258, 0.06230742],
#        [0.67158662, 0.32841338],
#        [0.07917054, 0.92082946],
#        [0.29093954, 0.70906046],
#        [0.9710587 , 0.0289413 ],
#        [0.95422167, 0.04577833],
#        [0.87211376, 0.12788624],
#        [0.86759677, 0.13240323],
#        [0.35284205, 0.64715795],
#        [0.51578626, 0.48421374],
#        [0.94425009, 0.05574991],
#        [0.64417764, 0.35582236],
#        [0.73640574, 0.26359426],
#        [0.92552334, 0.07447666],
#        [0.44942475, 0.55057525],
#        [0.69375195, 0.30624805],
#        [0.88075364, 0.11924636],
#        [0.94433099, 0.05566901],
#        [0.92541727, 0.07458273],
#        [0.90016914, 0.09983086],
#        [0.93107587, 0.06892413],
#        [0.93074199, 0.06925801],
#        [0.89213959, 0.10786041],
#        [0.8629453 , 0.1370547 ],
#        [0.93580541, 0.06419459],
#        [0.72170593, 0.27829407],
#        [0.88888419, 0.11111581],
#        [0.0660176 , 0.9339824 ],
#        [0.95103829, 0.04896171],
#        [0.58666439, 0.41333561],
#        [0.15306709, 0.84693291],
#        [0.37012255, 0.62987745],
#        [0.87211376, 0.12788624],
#        [0.9575842 , 0.0424158 ],
#        [0.85323015, 0.14676985],
#        [0.2549689 , 0.7450311 ],
#        [0.21921179, 0.78078821],
#        [0.91971848, 0.08028152],
#        [0.24343327, 0.75656673],
#        [0.91672234, 0.08327766],
#        [0.62415508, 0.37584492],
#        [0.95244662, 0.04755338],
#        [0.55956199, 0.44043801],
#        [0.52864295, 0.47135705],
#        [0.15270274, 0.84729726],
#        [0.90016914, 0.09983086],
#        [0.99141527, 0.00858473],
#        [0.90016914, 0.09983086],
#        [0.73443426, 0.26556574],
#        [0.90016914, 0.09983086],
#        [0.65883433, 0.34116567],
#        [0.12203624, 0.87796376],
#        [0.80609473, 0.19390527],
#        [0.84843454, 0.15156546],
#        [0.88459445, 0.11540555],
#        [0.05674927, 0.94325073],
#        [0.03872248, 0.96127752],
#        [0.87672742, 0.12327258],
#        [0.87380461, 0.12619539],
#        [0.03842392, 0.96157608],
#        [0.9071155 , 0.0928845 ],
#        [0.25914052, 0.74085948],
#        [0.24905986, 0.75094014],
#        [0.87179966, 0.12820034],
#        [0.73443426, 0.26556574],
#        [0.88459445, 0.11540555],
#        [0.82862183, 0.17137817],
#        [0.64417764, 0.35582236],
#        [0.86759677, 0.13240323],
#        [0.38888378, 0.61111622],
#        [0.91362489, 0.08637511],
#        [0.92552334, 0.07447666],
#        [0.46510919, 0.53489081],
#        [0.8501154 , 0.1498846 ],
#        [0.91362489, 0.08637511],
#        [0.81744904, 0.18255096],
#        [0.90016914, 0.09983086],
#        [0.6314384 , 0.3685616 ],
#        [0.88459445, 0.11540555],
#        [0.86759677, 0.13240323],
#        [0.21111455, 0.78888545],
#        [0.89276472, 0.10723528],
#        [0.26687483, 0.73312517],
#        [0.34493935, 0.65506065],
#        [0.4589354 , 0.5410646 ],
#        [0.63034269, 0.36965731],
#        [0.8629453 , 0.1370547 ],
#        [0.88888419, 0.11111581],
#        [0.79865513, 0.20134487],
#        [0.43793395, 0.56206605],
#        [0.87672742, 0.12327258],
#        [0.90016914, 0.09983086],
#        [0.85287749, 0.14712251],
#        [0.64116217, 0.35883783],
#        [0.25981227, 0.74018773],
#        [0.28676837, 0.71323163],
#        [0.88459445, 0.11540555],
#        [0.31684683, 0.68315317],
#        [0.21085856, 0.78914144],
#        [0.71044097, 0.28955903],
#        [0.90049697, 0.09950303],
#        [0.56113489, 0.43886511],
#        [0.09808858, 0.90191142],
#        [0.37012255, 0.62987745],
#        [0.79190858, 0.20809142],
#        [0.527281  , 0.472719  ],
#        [0.82884009, 0.17115991],
#        [0.91362489, 0.08637511],
#        [0.88459445, 0.11540555],
#        [0.64980908, 0.35019092],
#        [0.42813728, 0.57186272],
#        [0.91352418, 0.08647582],
#        [0.05262534, 0.94737466],
#        [0.94467239, 0.05532761],
#        [0.37012255, 0.62987745],
#        [0.19685329, 0.80314671],
#        [0.04358503, 0.95641497],
#        [0.90016914, 0.09983086],
#        [0.77845076, 0.22154924],
#        [0.91362489, 0.08637511],
#        [0.04188983, 0.95811017],
#        [0.73443426, 0.26556574],
#        [0.80994714, 0.19005286],
#        [0.90016914, 0.09983086],
#        [0.8764986 , 0.1235014 ],
#        [0.90016914, 0.09983086],
#        [0.93327045, 0.06672955],
#        [0.37012255, 0.62987745],
#        [0.26615159, 0.73384841],
#        [0.04878559, 0.95121441],
#        [0.46938588, 0.53061412],
#        [0.48728946, 0.51271054],
#        [0.19941143, 0.80058857],
#        [0.68066107, 0.31933893],
#        [0.91352418, 0.08647582],
#        [0.4580474 , 0.5419526 ],
#        [0.52743372, 0.47256628],
#        [0.38747417, 0.61252583],
#        [0.36637664, 0.63362336],
#        [0.1381839 , 0.8618161 ],
#        [0.90016914, 0.09983086],
#        [0.09313772, 0.90686228],
#        [0.05473017, 0.94526983],
#        [0.40277404, 0.59722596],
#        [0.4589354 , 0.5410646 ],
#        [0.9575842 , 0.0424158 ],
#        [0.87211376, 0.12788624],
#        [0.95236051, 0.04763949],
#        [0.90674431, 0.09325569],
#        [0.50872156, 0.49127844]])

# %% [markdown]
# ## 6 Evaluating Prediction Models

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, pred)
# Out:
# 0.7808988764044944

# %%
lr.coef_
# Out:
# array([[-1.18186729, -0.0399038 , -0.32076816,  0.00805085, -2.56836801,
#         -0.07487875, -0.23730722]])

# %%
pd.Series(lr.coef_[0], index = X.columns)
# Out:
# Pclass       -1.181867
# Age          -0.039904
# SibSp        -0.320768
# Parch         0.008051
# Sex_male     -2.568368
# Embarked_Q   -0.074879
# Embarked_S   -0.237307
# dtype: float64

# %% [markdown]
# ## 7 Apply some Feature Engineering

# %%
titanic_dum.columns
# Out:
# Index(['Pclass', 'Age', 'SibSp', 'Parch', 'Survived', 'Sex_male', 'Embarked_Q',
#        'Embarked_S'],
#       dtype='object')

# %%
titanic_dum['family'] = titanic_dum['SibSp'] + titanic_dum['Parch'] # sibling & spouse + Parent & child

# %%
titanic_dum.head()
# Out:
#    Pclass   Age  SibSp  Parch  Survived  Sex_male  Embarked_Q  Embarked_S  \
# 0       3  22.0      1      0         0      True       False        True
# 1       1  38.0      1      0         1     False       False       False
# 2       3  26.0      0      0         1     False       False        True
# 3       1  35.0      1      0         1     False       False        True
# 4       3  35.0      0      0         0      True       False        True
#
#    family
# 0       1
# 1       1
# 2       0
# 3       1
# 4       0

# %%
# Dose the prediction accuracy improved by 'engineering' "family variable?"
X = titanic_dum.drop(['Survived','SibSp','Parch'], axis = 1)
y = titanic_dum['Survived']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 100)
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 0.7921348314606742

# %%
# visualize the predicted performance: pink (false positive) and black (fasle nagative) bars represents incorrect prediction

import matplotlib.pyplot as plt

plt.figure(figsize=(16, 1))

plt.bar(range(len(y_test)), y_test+1, label='actual+1', color='black')
plt.bar(range(len(pred)), (pred+1), label='pred+1', color='red', alpha=0.5)

plt.xlabel('Index')
plt.ylabel('Value')
plt.title('Comparison of pred vs actual (y_test)')
plt.legend(ncol=3, loc=(0,1.01))
plt.show()
